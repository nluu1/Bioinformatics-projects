# %% [markdown]
# Nhi Luu
#
# BTEC330
#
# 05/11/2022
#
# HW4: Python with Panda in Jupyter Notebook
#
# # Please click the link to skip to section [Summary Plotting Challenge - Homework 4](#hw_4)

# %%
#Import Libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os

# %% [markdown]
# # Reading CSV Data

# %%
# Note that pd.read_csv is used because we imported pandas as pd
# makes sure this is pointed to the correct folder!
# use the 'surveys.csv file that you downloaded earlier'

##Print working directory:
os.getcwd() # 'C:\\Users\\Nhi\\Documents\\Python-projects\\Jupyter-notebooks'

#### I put the csv file in /Documents/Python-projects/Jupyter-notebooks/data-raw
pd.read_csv("data-raw/surveys.csv")
# Out:
#        record_id  month  day  year  plot_id species_id  sex  hindfoot_length  \
# 0              1      7   16  1977        2         NL    M             32.0
# 1              2      7   16  1977        3         NL    M             33.0
# 2              3      7   16  1977        2         DM    F             37.0
# 3              4      7   16  1977        7         DM    M             36.0
# 4              5      7   16  1977        3         DM    M             35.0
# ...          ...    ...  ...   ...      ...        ...  ...              ...
# 35544      35545     12   31  2002       15         AH  NaN              NaN
# 35545      35546     12   31  2002       15         AH  NaN              NaN
# 35546      35547     12   31  2002       10         RM    F             15.0
# 35547      35548     12   31  2002        7         DO    M             36.0
# 35548      35549     12   31  2002        5        NaN  NaN              NaN
#
#        weight
# 0         NaN
# ...

# %%
surveys_dfs = pd.read_csv("data-raw/surveys.csv")

# %%
surveys_dfs
# Out:
#        record_id  month  day  year  plot_id species_id  sex  hindfoot_length  \
# 0              1      7   16  1977        2         NL    M             32.0
# 1              2      7   16  1977        3         NL    M             33.0
# 2              3      7   16  1977        2         DM    F             37.0
# 3              4      7   16  1977        7         DM    M             36.0
# 4              5      7   16  1977        3         DM    M             35.0
# ...          ...    ...  ...   ...      ...        ...  ...              ...
# 35544      35545     12   31  2002       15         AH  NaN              NaN
# 35545      35546     12   31  2002       15         AH  NaN              NaN
# 35546      35547     12   31  2002       10         RM    F             15.0
# 35547      35548     12   31  2002        7         DO    M             36.0
# 35548      35549     12   31  2002        5        NaN  NaN              NaN
#
#        weight
# 0         NaN
# ...

# %%
surveys_df.head() # The head() method displays the first several lines of a file. It
                  # is discussed below.
# Out:
#    record_id  month  day  year  plot_id species_id sex  hindfoot_length  \
# 0          1      7   16  1977        2         NL   M             32.0
# 1          2      7   16  1977        3         NL   M             33.0
# 2          3      7   16  1977        2         DM   F             37.0
# 3          4      7   16  1977        7         DM   M             36.0
# 4          5      7   16  1977        3         DM   M             35.0
#
#    weight
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN

# %% [markdown]
# # Exploring Data

# %%
type(surveys_df)
# Out:
# pandas.core.frame.DataFrame

# %%
surveys_df.dtypes
# Out:
# record_id            int64
# month                int64
# day                  int64
# year                 int64
# plot_id              int64
# species_id          object
# sex                 object
# hindfoot_length    float64
# weight             float64
# dtype: object

# %% [markdown]
# ## Useful ways to view data frame objects in Python
# ### Challenge - data frames

# %%
surveys_df.columns
# Out:
# Index(['record_id', 'month', 'day', 'year', 'plot_id', 'species_id', 'sex',
#        'hindfoot_length', 'weight'],
#       dtype='object')

# %%
surveys_df.shape
# Out:
# (35549, 9)

# %%
surveys_df.head()
# Out:
#    record_id  month  day  year  plot_id species_id sex  hindfoot_length  \
# 0          1      7   16  1977        2         NL   M             32.0
# 1          2      7   16  1977        3         NL   M             33.0
# 2          3      7   16  1977        2         DM   F             37.0
# 3          4      7   16  1977        7         DM   M             36.0
# 4          5      7   16  1977        3         DM   M             35.0
#
#    weight
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN

# %%
surveys_df.head(15)
# Out:
#     record_id  month  day  year  plot_id species_id  sex  hindfoot_length  \
# 0           1      7   16  1977        2         NL    M             32.0
# 1           2      7   16  1977        3         NL    M             33.0
# 2           3      7   16  1977        2         DM    F             37.0
# 3           4      7   16  1977        7         DM    M             36.0
# 4           5      7   16  1977        3         DM    M             35.0
# 5           6      7   16  1977        1         PF    M             14.0
# 6           7      7   16  1977        2         PE    F              NaN
# 7           8      7   16  1977        1         DM    M             37.0
# 8           9      7   16  1977        1         DM    F             34.0
# 9          10      7   16  1977        6         PF    F             20.0
# 10         11      7   16  1977        5         DS    F             53.0
# 11         12      7   16  1977        7         DM    M             38.0
# ...

# %%
surveys_df.tail()
# Out:
#        record_id  month  day  year  plot_id species_id  sex  hindfoot_length  \
# 35544      35545     12   31  2002       15         AH  NaN              NaN
# 35545      35546     12   31  2002       15         AH  NaN              NaN
# 35546      35547     12   31  2002       10         RM    F             15.0
# 35547      35548     12   31  2002        7         DO    M             36.0
# 35548      35549     12   31  2002        5        NaN  NaN              NaN
#
#        weight
# 35544     NaN
# 35545     NaN
# 35546    14.0
# 35547    51.0
# 35548     NaN

# %% [markdown]
# # Calculating statistics from data in Panda data frames

# %%
surveys_df.columns
# Out:
# Index(['record_id', 'month', 'day', 'year', 'plot_id', 'species_id', 'sex',
#        'hindfoot_length', 'weight'],
#       dtype='object')

# %%
#The pd.unique function tells us all of the unique values in the species_id column.
pd.unique(surveys_df['species_id'])
# Out:
# array(['NL', 'DM', 'PF', 'PE', 'DS', 'PP', 'SH', 'OT', 'DO', 'OX', 'SS',
#        'OL', 'RM', nan, 'SA', 'PM', 'AH', 'DX', 'AB', 'CB', 'CM', 'CQ',
#        'RF', 'PC', 'PG', 'PH', 'PU', 'CV', 'UR', 'UP', 'ZL', 'UL', 'CS',
#        'SC', 'BA', 'SF', 'RO', 'AS', 'SO', 'PI', 'ST', 'CU', 'SU', 'RX',
#        'PB', 'PL', 'PX', 'CT', 'US'], dtype=object)

# %% [markdown]
# ### Challenge - statistics

# %%
site_names = pd.unique(surveys_df['plot_id'])
site_names
# Out:
# array([ 2,  3,  7,  1,  6,  5,  8,  4, 11, 14, 15, 13,  9, 10, 17, 16, 20,
#        23, 18, 21, 22, 19, 12, 24], dtype=int64)

# %%
len(site_names) #length of all elements in list
# Out:
# 24

# %%
surveys_df['plot_id'].nunique() #include all unique elements for each column
# Out:
# 24

# %% [markdown]
# # Groups in Pandas

# %%
surveys_df['weight'].describe()
# Out:
# count    32283.000000
# mean        42.672428
# std         36.631259
# min          4.000000
# 25%         20.000000
# 50%         37.000000
# 75%         48.000000
# max        280.000000
# Name: weight, dtype: float64

# %%
#IF we want specific metric, use each function
surveys_df['weight'].min()
surveys_df['weight'].max()
surveys_df['weight'].mean()
surveys_df['weight'].std()
surveys_df['weight'].count()
# Out:
# 32283

# %%
#ELSE, use groupby()
grouped_data = surveys_df.groupby('sex')

# %%
# Summary statistics for all numeric columns by sex
grouped_data.describe()
# Provide the mean for each numeric column by sex
grouped_data.mean()
# Out:
#         record_id     month        day         year    plot_id  \
# sex
# F    18036.412046  6.587253  15.880943  1990.644997  11.440854
# M    17754.835601  6.396184  16.078799  1990.480401  11.098282
#
#      hindfoot_length     weight
# sex
# F          28.836780  42.170555
# M          29.709578  42.995379

# %% [markdown]
# ### Challenge - Summary Data

# %% [markdown]
# #Recorded individuals are female (F) is:
#
# #Recorded individuals are male (M) is:

# %%
grouped_data2 = surveys_df.groupby(['plot_id', 'sex'])

# %%
grouped_data2.mean()

#Same thing happen (?)
# Out:
#                 record_id     month        day         year  hindfoot_length  \
# plot_id sex
# 1       F    18390.384434  6.597877  15.338443  1990.933962        31.733911
#         M    17197.740639  6.121461  15.905936  1990.091324        34.302770
# 2       F    17714.753608  6.426804  16.288660  1990.449485        30.161220
#         M    18085.458042  6.340035  15.440559  1990.756119        30.353760
# 3       F    19888.783875  6.610302  15.993281  1992.013438        23.774044
#         M    20226.767857  6.277381  16.271429  1992.275000        23.833744
# 4       F    17489.205275  6.447248  15.608945  1990.235092        33.249102
#         M    18493.841748  6.436893  16.303883  1991.000971        34.097959
# 5       F    12280.793169  6.142315  15.722960  1986.485769        28.921844
#         M    12798.426621  6.194539  15.703072  1986.817406        29.694794
# 6       F    19406.503392  6.640434  15.947083  1991.579376        26.981322
# ...

# %%
by_site = surveys_df.groupby('plot_id')
by_site.mean()
# Out:
#             record_id     month        day         year  hindfoot_length  \
# plot_id
# 1        17674.516792  6.307769  15.646617  1990.428070        33.186760
# 2        17669.809480  6.378760  15.760711  1990.429353        30.259519
# 3        19768.905361  6.475930  16.102845  1991.931072        23.803327
# 4        17998.813611  6.429660  15.997461  1990.625190        33.697636
# 5        13133.017588  6.202680  15.762982  1987.082077        29.322306
# 6        18579.403287  6.316688  15.967762  1991.035398        27.201129
# 7        18080.537990  6.583333  15.437500  1990.680147        20.167203
# 8        19161.210999  6.585405  15.497620  1991.467478        33.025143
# 9        17295.930785  6.431818  15.161674  1990.107438        34.594318
# 10       16180.501066  6.098081  16.249467  1989.330490        19.088561
# 11       17002.651199  6.549531  15.898332  1989.872784        32.054679
# 12       17383.576744  6.369979  16.253700  1990.229598        31.406425
# ...

# %%
by_site['weight'].describe() #print all
by_site['weight'].describe().head(1) #print snipple same as solution for #3
# Out:
#           count       mean       std  min   25%   50%   75%    max
# plot_id
# 1        1903.0  51.822911  38.17667  4.0  30.0  44.0  53.0  231.0

# %% [markdown]
# # Quickly create summary counts in Pandas

# %%
# Count the number of samples by species
species_counts = surveys_df.groupby('species_id')['record_id'].count()
print(species_counts)
# Out:
# species_id
# AB      303
# AH      437
# AS        2
# BA       46
# CB       50
# CM       13
# CQ       16
# CS        1
# CT        1
# CU        1
# CV        1
# DM    10596
# DO     3027
# DS     2504
# DX       40
# NL     1252
# OL     1006
# OT     2249
# OX       12
# PB     2891
# PC       39
# PE     1299
# PF     1597
# PG        8
# PH       32
# PI        9
# PL       36
# PM      899
# PP     3123
# PU        5
# PX        6
# RF       75
# RM     2609
# RO        8
# RX        2
# SA       75
# SC        1
# SF       43
# SH      147
# SO       43
# SS      248
# ST        1
# SU        5
# UL        4
# UP        8
# UR       10
# US        4
# ZL        2
# Name: record_id, dtype: int64

# %%
#OR 
surveys_df.groupby('species_id')['record_id'].count()['DO']
# Out:
# 3027

# %% [markdown]
# ## Basic Math Functions

# %%
# Multiply all weight values by 2
surveys_df['weight']*2
# Out:
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
#          ...
# 35544      NaN
# 35545      NaN
# 35546     28.0
# 35547    102.0
# 35548      NaN
# Name: weight, Length: 35549, dtype: float64

# %% [markdown]
# # Quick and Easy Plotting Data Using Pandas

# %%
# Make sure figures appear inline in Ipython Notebook
# %matplotlib inline
# Create a quick bar chart
species_counts.plot(kind='bar');

# %%
total_count = surveys_df.groupby('plot_id')['record_id'].nunique()
# Let's plot that too
total_count.plot(kind='bar');

# %% [markdown]
# ## Challenge
# ### Challenge - Plots

# %%
# Create a plot of average weight across all species per site:

species_counts.plot(kind='bar');
total_count = surveys_df.groupby('plot_id')['weight'].nunique()
total_count.plot(kind='bar');

# %%
# Create a plot of total males versus total females for the entire dataset.

species_counts.plot(kind='bar');
total_count = surveys_df.groupby('sex')['record_id'].nunique()
total_count.plot(kind='bar');

# %% [markdown]
# <a id='hw_4'></a>
#
# # Summary Plotting Challenge - Homework 4

# %%
# group data by site and by sex
by_site_sex = surveys_df.groupby(['plot_id', 'sex'])

# %%
# calculate a total for each site
site_sex_count = by_site_sex['weight'].sum()
site_sex_count
# Out:
# plot_id  sex
# 1        F      38253.0
#          M      59979.0
# 2        F      50144.0
#          M      57250.0
# 3        F      27251.0
#          M      28253.0
# 4        F      39796.0
#          M      49377.0
# 5        F      21143.0
#          M      23326.0
# 6        F      26210.0
#          M      27245.0
# 7        F       6522.0
#          M       6422.0
# 8        F      37274.0
#          M      47755.0
# 9        F      44128.0
#          M      48727.0
# 10       F       2359.0
#          M       2776.0
# 11       F      34638.0
#          M      43106.0
# 12       F      51825.0
#          M      57420.0
# 13       F      24720.0
#          M      30354.0
# 14       F      32770.0
#          M      46469.0
# 15       F      12455.0
#          M      11037.0
# 16       F       5446.0
#          M       6310.0
# 17       F      42106.0
#          M      48082.0
# 18       F      27353.0
#          M      26433.0
# 19       F      11297.0
# ...

# %%
# figure out the total weight that each sex contributed to each site.
by_site_sex = surveys_df.groupby(['plot_id', 'sex'])
site_sex_count = by_site_sex['weight'].sum()
site_sex_count.unstack()
# Out:
# sex            F        M
# plot_id
# 1        38253.0  59979.0
# 2        50144.0  57250.0
# 3        27251.0  28253.0
# 4        39796.0  49377.0
# 5        21143.0  23326.0
# 6        26210.0  27245.0
# 7         6522.0   6422.0
# 8        37274.0  47755.0
# 9        44128.0  48727.0
# 10        2359.0   2776.0
# 11       34638.0  43106.0
# 12       51825.0  57420.0
# 13       24720.0  30354.0
# 14       32770.0  46469.0
# 15       12455.0  11037.0
# 16        5446.0   6310.0
# 17       42106.0  48082.0
# 18       27353.0  26433.0
# 19       11297.0  11514.0
# 20       33206.0  25988.0
# 21       15481.0   9815.0
# 22       34656.0  35363.0
# 23        3352.0   3883.0
# 24       22951.0  18835.0

# %%
#stacked bar plot with that data where the weights for each sex are stacked by site
by_site_sex = surveys_df.groupby(['plot_id', 'sex'])
site_sex_count = by_site_sex['weight'].sum()
spc = site_sex_count.unstack()
s_plot = spc.plot(kind='bar', stacked=True, title="Total weight by site and sex")
s_plot.set_ylabel("Weight")
s_plot.set_xlabel("Plot")
# Out:
# Text(0.5, 0, 'Plot')
